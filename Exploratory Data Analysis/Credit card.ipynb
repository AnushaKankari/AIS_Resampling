# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/kanka/OneDrive/Desktop/Final Project/Datasets/credit.csv',  delimiter=',')

df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
print(df['Class'].value_counts())
# Out:
# 0    23364
# 1     6636
# Name: Class, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         30000 non-null  int64
#  1   LIMIT_BAL  30000 non-null  int64
#  2   SEX        30000 non-null  int64
#  3   EDUCATION  30000 non-null  int64
#  4   MARRIAGE   30000 non-null  int64
#  5   AGE        30000 non-null  int64
#  6   PAY_0      30000 non-null  int64
#  7   PAY_2      30000 non-null  int64
#  8   PAY_3      30000 non-null  int64
#  9   PAY_4      30000 non-null  int64
#  10  PAY_5      30000 non-null  int64
#  11  PAY_6      30000 non-null  int64
#  12  BILL_AMT1  30000 non-null  int64
#  13  BILL_AMT2  30000 non-null  int64
#  14  BILL_AMT3  30000 non-null  int64
#  15  BILL_AMT4  30000 non-null  int64
#  16  BILL_AMT5  30000 non-null  int64
#  17  BILL_AMT6  30000 non-null  int64
#  18  PAY_AMT1   30000 non-null  int64
#  19  PAY_AMT2   30000 non-null  int64
# ...

# %%
c = df.isnull().sum()
plt.title("Missing data statistics")
c.plot(kind='line')
print(c)
# Out:
# ID           0
# LIMIT_BAL    0
# SEX          0
# EDUCATION    0
# MARRIAGE     0
# AGE          0
# PAY_0        0
# PAY_2        0
# PAY_3        0
# PAY_4        0
# PAY_5        0
# PAY_6        0
# BILL_AMT1    0
# BILL_AMT2    0
# BILL_AMT3    0
# BILL_AMT4    0
# BILL_AMT5    0
# BILL_AMT6    0
# PAY_AMT1     0
# PAY_AMT2     0
# PAY_AMT3     0
# PAY_AMT4     0
# PAY_AMT5     0
# PAY_AMT6     0
# Class        0
# dtype: int64

# %%
df['Class'].value_counts().plot(kind='bar', title='Target field distribution');
plt.ylabel('Count')
plt.xlabel('Class (Non-Fraud:0, Fraud:1)')
plt.show()

# %%
Non_default, Default = df['Class'].value_counts()
print('Count of Non-Default clients', Non_default)
print('Count of Default clients', Default)
sns.countplot(x="Class", hue="Class", data=df)
plt.ylabel('Count')
plt.xlabel('Class (0:Non-Default, 1:Default)')
plt.title('Distribution of the target field')
plt.show()
# Out:
# Count of Non-Default clients 23364
# Count of Default clients 6636

# %%
plt.figure(figsize=(9,4))
plt.title('Distribution of previous payment in April 2005')
sns.distplot(df['PAY_AMT6'], rug= True, rug_kws={'color': 'red'}) 
#Hist = False or rug = True (give data points details)
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
plt.figure(figsize=(7,4))
plt.title('Distribution of bill statement amount in April 2005')
sns.distplot(df['BILL_AMT6'], rug= True, rug_kws={'color': 'red'}) 
#Hist = False or rug = True (give data points details)
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
plt.figure(figsize=(9,4))
plt.title('Distribution of Limit balance')
sns.distplot(df['LIMIT_BAL'], rug= True, rug_kws={'color': 'red'}) 
#Hist = False or rug = True (give data points details)
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
print(df['PAY_0'].value_counts())
df['PAY_0'].value_counts().plot(kind='bar', title='Count of Payment 6');
# Out:
#  0    14737
# -1     5686
#  1     3688
# -2     2759
#  2     2667
#  3      322
#  4       76
#  5       26
#  8       19
#  6       11
#  7        9
# Name: PAY_0, dtype: int64

# %%
female, male = df['SEX'].value_counts()
print('Count of female', female)
print('Count of male', male)
df['SEX'].value_counts().plot(kind='bar', title='Sex distribution ');
# Out:
# Count of female 18112
# Count of male 11888

# %%
print(df.groupby(['SEX','MARRIAGE']).size())
df.groupby(['SEX','MARRIAGE']).size().unstack().plot(kind='bar',stacked=True)
# Out:
# SEX  MARRIAGE
# 1    0             14
#      1           5190
#      2           6553
#      3            131
# 2    0             40
#      1           8469
#      2           9411
#      3            192
# dtype: int64

# %%
plt.figure(figsize=(17, 7))
print (df.boxplot())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
plt.figure(figsize=(13, 13))
bplot = sns.boxplot(data=df['AGE'],
                 width=0.7,
                 palette="colorblind",linewidth=0.9)

# %%
# https://towardsdatascience.com/ways-to-detect-and-remove-the-outliers-404d16608dba
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# ID            14999.50
# LIMIT_BAL    190000.00
# SEX               1.00
# EDUCATION         1.00
# MARRIAGE          1.00
# AGE              13.00
# PAY_0             1.00
# PAY_2             1.00
# PAY_3             1.00
# PAY_4             1.00
# PAY_5             1.00
# PAY_6             1.00
# BILL_AMT1     63532.25
# BILL_AMT2     61021.50
# BILL_AMT3     57498.50
# BILL_AMT4     52179.25
# BILL_AMT5     48427.50
# BILL_AMT6     47942.25
# PAY_AMT1       4006.00
# PAY_AMT2       4167.00
# PAY_AMT3       4115.00
# PAY_AMT4       3717.25
# PAY_AMT5       3779.00
# PAY_AMT6       3882.25
# Class             0.00
# dtype: float64

# %%
print(boston_df_o1 < (Q1 - 1.5 * IQR)) |(boston_df_o1 > (Q3 + 1.5 * IQR))
# Out:
#           ID  LIMIT_BAL    SEX  EDUCATION  MARRIAGE    AGE  PAY_0  PAY_2  \
# 0      False      False  False      False     False  False  False  False
# 1      False      False  False      False     False  False  False  False
# 2      False      False  False      False     False  False  False  False
# 3      False      False  False      False     False  False  False  False
# 4      False      False  False      False     False  False  False  False
# ...      ...        ...    ...        ...       ...    ...    ...    ...
# 29995  False      False  False      False     False  False  False  False
# 29996  False      False  False      False     False  False  False  False
# 29997  False      False  False      False     False  False  False  False
# 29998  False      False  False      False     False  False  False  False
# 29999  False      False  False      False     False  False  False  False
#
#        PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ...

# %%
plt.figure(figsize=(15,10))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
plt.figure(figsize=(15,10))
cor = df.corr(method='pearson')
ax = sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
plt.show()

# %%
cor_target = cor["Class"]
print(cor_target)
# Out:
# ID          -0.013952
# LIMIT_BAL   -0.153520
# SEX         -0.039961
# EDUCATION    0.028006
# MARRIAGE    -0.024339
# AGE          0.013890
# PAY_0        0.324794
# PAY_2        0.263551
# PAY_3        0.235253
# PAY_4        0.216614
# PAY_5        0.204149
# PAY_6        0.186866
# BILL_AMT1   -0.019644
# BILL_AMT2   -0.014193
# BILL_AMT3   -0.014076
# BILL_AMT4   -0.010156
# BILL_AMT5   -0.006760
# BILL_AMT6   -0.005372
# PAY_AMT1    -0.072929
# PAY_AMT2    -0.058579
# PAY_AMT3    -0.056250
# PAY_AMT4    -0.056827
# PAY_AMT5    -0.055124
# PAY_AMT6    -0.053183
# Class        1.000000
# Name: Class, dtype: float64

# %%
plt.title("Pearson Coefficient of features correlation on target attribute")
cor_target.plot(kind='barh')

# %%
plt.figure(figsize=(15,10))
kendall_corr = df.corr(method='kendall')
ax = sns.heatmap(kendall_corr, annot=True, cmap=plt.cm.Reds)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
plt.show()

# %%
kendall_corr_target = abs(kendall_corr["Class"])
print(kendall_corr_target)
# Out:
# ID           0.011392
# LIMIT_BAL    0.141088
# SEX          0.039961
# EDUCATION    0.042070
# MARRIAGE     0.026330
# AGE          0.004273
# PAY_0        0.267885
# PAY_2        0.201556
# PAY_3        0.181077
# PAY_4        0.162047
# PAY_5        0.148829
# PAY_6        0.133028
# BILL_AMT1    0.020724
# BILL_AMT2    0.012741
# BILL_AMT3    0.010389
# BILL_AMT4    0.006859
# BILL_AMT5    0.005629
# BILL_AMT6    0.000063
# PAY_AMT1     0.133076
# PAY_AMT2     0.125263
# PAY_AMT3     0.116012
# PAY_AMT4     0.106797
# PAY_AMT5     0.097453
# PAY_AMT6     0.101760
# Class        1.000000
# Name: Class, dtype: float64

# %%
plt.title("Kendall Tau features correlation on target attribute")
kendall_corr_target.plot(kind='bar')

# %%
plt.figure(figsize=(15,10))
spearman_corr = df.corr(method='spearman')
ax = sns.heatmap(spearman_corr, annot=True, cmap=plt.cm.Reds)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
plt.show()

# %%
spearman_corr_target = spearman_corr["Class"]
print(spearman_corr_target)
# Out:
# ID          -0.013952
# LIMIT_BAL   -0.169586
# SEX         -0.039961
# EDUCATION    0.044369
# MARRIAGE    -0.026490
# AGE          0.005149
# PAY_0        0.292213
# PAY_2        0.216919
# PAY_3        0.194771
# PAY_4        0.173690
# PAY_5        0.159043
# PAY_6        0.142523
# BILL_AMT1   -0.025327
# BILL_AMT2   -0.015554
# BILL_AMT3   -0.012670
# BILL_AMT4   -0.008357
# BILL_AMT5   -0.006851
# BILL_AMT6   -0.000076
# PAY_AMT1    -0.160493
# PAY_AMT2    -0.150977
# PAY_AMT3    -0.139388
# PAY_AMT4    -0.127979
# PAY_AMT5    -0.116587
# PAY_AMT6    -0.121444
# Class        1.000000
# Name: Class, dtype: float64

# %%
plt.title("Spearman rank features correlation on target attribute")
spearman_corr_target.plot(kind='barh')

# %%
fig, ax = plt.subplots(figsize=(6,6))
ax.scatter(df['BILL_AMT1'], df['BILL_AMT4'])
ax.set_xlabel('BILL_AMT1')
ax.set_ylabel('BILL_AMT4')
plt.title('Scatter plot for BILL_AMT1 Vs BILL_AMT4')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6,6))
ax.scatter(df['BILL_AMT4'], df['BILL_AMT5'])
ax.set_xlabel('BILL_AMT4')
ax.set_ylabel('BILL_AMT5')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig_3D = plt.figure(figsize=(10,10))
ax_3D = fig_3D.add_subplot(111, projection = '3d')

x = df['BILL_AMT1']
y = df['BILL_AMT4']
z = df['BILL_AMT5']

ax_3D.scatter(x, y, z)
ax_3D.set_xlabel("BILL_AMT1")
ax_3D.set_ylabel("BILL_AMT4")
ax_3D.set_zlabel("BILL_AMT5")

plt.title('3D Scatter plot for BILL_AMT1, BILL_AMT4, BILL_AMT5')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig_3D = plt.figure(figsize=(10,10))
ax_3D = fig_3D.add_subplot(111, projection = '3d')

x = df['PAY_2']
y = df['PAY_3']
z = df['PAY_4']

ax_3D.scatter(x, y, z)
ax_3D.set_xlabel("PAY_2")
ax_3D.set_ylabel("PAY_3")
ax_3D.set_zlabel("PAY_4")

plt.title('3D Scatter plot for PAY_2, PAY_3, PAY_4')
plt.show()

# %%
y = df['Class']
x = df.drop('Class', axis=1)
print(x)
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(x,y)
#print(model.feature_importances_)

feat_importances = pd.Series(model.feature_importances_, index=(df.drop('Class', axis=1)).columns)
feat_importances.nlargest(25).plot(kind='barh')
plt.title('Random Forest Feature Importance')
plt.show()

# %%
from sklearn.inspection import permutation_importance


# perform permutation importance
results = permutation_importance(model, x, y, scoring='accuracy')
# get importance
importance = results.importances_mean

Permutation_feat_importances = pd.Series(importance, index=(df.drop('Class', axis=1)).columns)
Permutation_feat_importances.nlargest(25).plot(kind='barh')
plt.title('Permutation Feature Importance')
plt.show()
